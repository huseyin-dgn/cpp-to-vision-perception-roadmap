# %% [markdown]
# # 📌 Uygulama – 2
# # 🖼️ OpenCV ile Resim Okuma ve Gösterme
# (OpenCV + cv::Mat Temelleri)
#
# ---
#
# ## 🎯 1) Amaç — *Bu projede ne yaptım?*
#
# Bu uygulamada amacım:
#
# **OpenCV kullanarak bir resmi C++ tarafında okumak, `cv::Mat` formatında işlemek ve ekranda göstermekti.**
#
# Bu, LibTorch tarafında görüntüyü tensöre çevirmeden önceki temel adımdır.
#
#
# ## 🧩 2) Ana Adımlar — *Kodda yaptığım işlemler*
#
# 1. **Resmi diskte aradım ve okudum**
# ```cpp
#    cv::Mat img = cv::imread("test.jpg");
# ```
#
# Yükleme başarısızsa hata verdim
# ```cpp
# if (img.empty()) { ... }
# ```
#
#
# Resmin boyutlarını ekrana yazdım
# ```cpp
# img.cols, img.rows
# ```
#
#
# Resmi bir pencereye çizdim
# ```cpp
# cv::imshow("Görüntü", img);
# ```
#
#
# Kullanıcı tuşa basana kadar görüntünün açık kalmasını sağladım
# ```cpp
# cv::waitKey(0);
# ```
#
#
# Hata kontrolü için try/catch kullandım
#
# ## 🧠 3) Bu projedeki temel kavramlar
#
# 📌 cv::Mat → OpenCV'nin görüntü veri yapısı
#
# 📌 cv::imread → Diskten görüntü okuma
#
# 📌 cv::imshow → Görüntüyü pencerede gösterme
#
# 📌 cv::waitKey → Pencereyi açık tutma
#
# 📌 Görüntünün genişlik & yükseklik bilgisi (cols, rows)
#
# 📌 Hata yakalama işlemleri (try/catch)
#
# Bu bilgiler ileride gerekli olacak:
#
# * preprocess (RGB, resize, normalize),
#
# * webcam işlemleri,
#
# * LibTorch tensör dönüşümleri.
#
# ## 🚀 4) Sonraki Adımda Neler Yapılabilir?
#
# Bu temel yapı üzerine ek olarak:
#
# 🟦 Resmi yeniden boyutlandırmak → cv::resize
#
# 🟥 BGR → RGB dönüşümü
#
# 🟨 Görüntüyü float32 yapıp 0–1 normalize etmek
#
# 🟩 cv::Mat → torch::Tensor dönüşümüne geçmek (bir sonraki uygulama)
#
# 🎥 Webcam görüntüsü almak
#
# ✏️ Görsel üzerine çizim yapmak (bbox, text, fps)
#
# ## 🔖 5) Etiketler / Kategori
#
# OpenCV Basics
#
# cv::Mat
#
# Image Display
#
# imread
#
# imshow
#
# Beginner
#
# ## 📝 6) Tek Cümlelik Özet
#
# test.jpg dosyasını OpenCV ile okudum, cv::Mat formatında işledim ve ekrana göstererek görüntü işleme pipeline’ının temelini attım.
