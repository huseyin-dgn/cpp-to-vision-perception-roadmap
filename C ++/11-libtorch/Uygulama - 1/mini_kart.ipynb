# %% [markdown]
# # ✅ LibTorch Mini Kart – Uygulama 1
# ## 📌 Proje: “TorchScript Modelini C++'ta Yükleme ve Dummy Input ile Forward”
# ### 1) Amaç (Ben burada ne yaptım?)
#
# Bu projede aslında şunu yaptım:
#
# * Python’da TorchScript’e çevirdiğim bir modeli ilk kez C++ tarafında yükleyip
# **dummy bir input ile forward çalıştırarak LibTorch pipeline’ının temelini kurdum.**
#
# Yani ilk defa:
#
# * TorchScript modelini C++’a çektim,
#
# * C++ tarafında torch::jit::load kullandım,
#
# * vectorIValue> hazırladım,
#
# * forward() çağırdım,
#
# * çıktının shape’ini ve tensörü ekrana bastım.
#
# Bu, LibTorch çalışma mantığını anlamam için kritik ilk adımdı.
#
# ### 2) Ana adımlar (Kodda yaptığım işler)
#
# Bu projede adımlarım şunlardı:
#
# * model_ts.pt dosyasını kontrol ettim
#
# * C++ exe ile aynı klasörde mi?
#
# * Dosya yoksa hata verip programı kapatıyorum.
#
# * TorchScript modelini yükledim
#
# * torch::jit::load(model_path)
#
# * Model başarıyla alındı mı kontrol ettim.
#
# * Modeli cihaz seçimi + eval moduna aldım
#
# * module.to(torch::kCPU);
#
# * module.eval();
#
# * Dummy bir tensör oluşturdum
#
# * torch::randn({1,10})
#
# * Yani 1x10 boyutlu rastgele input.
#
# * Forward() için input listesi hazırladım
#
# **std::vectortorch::jit::IValue>**
#
# * Forward çağırıp çıktıyı aldım
#
# **module.forward(inputs).toTensor()**
#
# * Output shape & tensörü ekrana yazdırdım
#
# * Hem input hem output boyutlarına baktım.
#
# ### 3) Bu projede öğrendiğim kavramlar
#
# Bu proje bana şunları öğretti:
#
# * TorchScript modelinin C++’ta nasıl yüklendiği
#
# * torch::jit::script::Module sınıfı
#
# * Input olarak neden IValue listesi kullandığı
#
# * Forward çağrısının C++ tarafındaki akışı
#
# * Tensor’ü ekrana nasıl basacağım
#
# * C++’ta hata yönetimi (c10::Error) mantığı
#
# * LibTorch’un “her şey tensör” yapısına alışma
#
# * Model dosyası exe ile aynı klasörde olmak zorunda
#
# * LibTorch dünyasına yumuşak ama temiz bir giriş yaptım.
#
# ### 4) Bu projenin etiketi (kategorisi)
#
# Bu proje şu başlık altına girer:
#
# * TorchScript Load
#
# * Model Forward
#
# * Basic LibTorch
#
# * Dummy Input
#
# * IValue Pipeline
#
# * Fundamentals
#
# Bu, tamamen seviye 1 başlangıç projesi.
#
# ## 6) Projeyi tek cümlede özetle
#
# * TorchScript modelini C++’ta yükledim, dummy tensörle forward çalıştırdım ve LibTorch’un temel çalışma mekanizmasını öğrendim.
