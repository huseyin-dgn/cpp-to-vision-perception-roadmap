# %% [markdown]
# # 📘 Sıralama Algoritmaları – Teorik Özet
#
# Bu bölümde tüm temel sıralama algoritmalarının mantığını **kodsuz**, sadece **teorik** olarak açıklıyoruz.
#
# ---
#
# ## 🔹 1. Bubble Sort (Kabarcık Sıralama)
#
# Bubble Sort, diziyi tekrar tekrar dolaşarak **yan yana duran iki elemanı karşılaştırır**.
#
# - Eğer soldaki > sağdaki ise **swap** yapılır.
# - Her tam geçişte en büyük eleman **sona doğru “yüzer”**.
# - Dizi tamamen sıralanana kadar işlem sürer.
#
# **Zaman Karmaşıklığı:**
# - Ortalama: O(n²)
# - Kötü: O(n²)
# - En iyi: O(n) (dizi sıralıysa)
#
# ---
#
# ## 🔹 2. Selection Sort (Seçmeli Sıralama)
#
# Diziyi soldan sağa ilerler.
#
# - Her adımda kalan kısım içinden **en küçük elemanı bulur**.
# - Bulduğu en küçüğü **baş tarafla yer değiştirir**.
# - Sonra ikinci en küçüğü bulur, ikinci sıraya koyar…
#
# Her adım “minimum seçme” mantığına dayanır.
#
# **Zaman Karmaşıklığı:**
# Her durumda O(n²) (aranan minimum yüzünden)
#
# ---
#
# ## 🔹 3. Insertion Sort (Eklemeli Sıralama)
#
# Gerçek hayatta kart dizmeye benzer.
#
# - İlk elemanı zaten sıralı kabul eder.
# - Sonraki her elemanı, soldaki sıralı bölgenin **doğru yerine “sokuşturur”**.
# - Elemanlar sağa doğru kaydırılarak boşluk açılır.
#
# **Avantaj:**
# Küçük dizilerde ve neredeyse sıralı dizilerde **çok hızlıdır**.
#
# **Zaman Karmaşıklığı:**
# - Ortalama: O(n²)
# - En iyi: O(n)
# - En kötü: O(n²)
#
# ---
#
# ## 🔹 4. Merge Sort (Birleştirmeli Sıralama)
#
# Böl–fethet (divide and conquer) mantığıyla çalışır.
#
# 1. Dizi **yarılara bölünür**
# 2. Her yarı **rekürsif olarak sıralanır**
# 3. İki sıralı yarı **birleştirilerek** tek bir sıralı dizi elde edilir
#
# Her zaman oldukça hızlıdır.
#
# **Zaman Karmaşıklığı:**
# - Her durumda O(n log n)
#
# ---
#
# ## 🔹 5. Quick Sort (Hızlı Sıralama)
#
# Yine divide & conquer yaklaşımı.
#
# - Bir **pivot** seçilir
# - Dizi pivot’tan küçükler ve büyükler olarak **ikiye ayrılır**
# - Her kısım rekürsif olarak sıralanır
# - Pivot orta yere oturur
#
# Çok hızlı çalışabilir.
#
# **Zaman Karmaşıklığı:**
# - Ortalama: O(n log n)
# - En kötü: O(n²) (pivot kötü seçilirse)
#
# ---
#
# ## 🔹 6. Heap Sort
#
# Binary heap yapısını kullanır.
#
# 1. Diziden bir **max-heap** oluşturulur
# 2. En büyük eleman heap kökündedir → alınır, sona koyulur
# 3. Heap küçülür ve yeniden düzenlenir (heapify)
# 4. Bu işlem dizi sıralanana kadar devam eder
#
# **Zaman Karmaşıklığı:**
# - Her durumda O(n log n)
#
# ---
#
# ## 🔹 7. Counting Sort (Sayma Sıralaması)
#
# Karşılaştırma yapmaz.
#
# - Dizi değerleri belirli küçük bir aralıktaysa (örneğin 0–100),
# - Elemanların frekansını sayar,
# - Bu frekanslarla sıralı diziyi oluşturur.
#
# Süper hızlıdır ama aralık küçük olmak zorunda.
#
# **Zaman Karmaşıklığı:**
# - O(n + k)  → k = sayı aralığı
#
# ---
#
# ## 🔹 8. Radix Sort (Basamak Sıralaması)
#
# Sayıları **basamak basamak** sıralar.
#
# - Birlikler basamağına göre sırala
# - Sonra onlar basamağına göre sırala
# - Sonra yüzler…
#
# Her basamakta Counting Sort kullanır.
#
# **Zaman Karmaşıklığı:**
# O(d × (n + k))
# d = basamak sayısı
#
# ---
#
# ## 🔹 9. Bucket Sort
#
# Dizi değerleri belirli bir aralıkta ve **uniform dağılmışsa**:
#
# - Elemanlar “kovalara” dağıtılır
# - Her kova kendi içinde sıralanır (genelde insertion sort)
# - Korlar birleştirilir
#
# Doğru koşullarda çok hızlıdır.
#
# ---
#
# # 🎯 Özet
#
# - O(n²) algoritmalar → Bubble, Selection, Insertion
# - O(n log n) algoritmalar → Merge, Quick, Heap
# - Özel durumlar için → Counting, Radix, Bucket
#
# Şimdi bu algoritmaları kodlamaya geçebiliriz.
